# %% [markdown]
# # ASSIGNMENT(Deadline: Mon, Oct 5)

# %% [markdown]
# For your first task, you are to create the following charts as seen below with the data provided to you.
# You are to make sure that the code used in the creating of the charts runs without error before sendinf in the ipynb file

# %% [markdown]
# Create the charts below, using the exact colors.
# Note: Create your own dataframe and use any values as you see fit.
#
# After creating the charts, make sure you annotate the values on each bar.
#
# Every other thing including the text on the diagram must be included in the chart you are creating must remain the same
#
# Make sure you include the two titles

# %% [markdown]
# ![5.11.png](attachment:5.11.png)

# %% [markdown]
# ![5.3.png](attachment:5.3.png)

# %% [markdown]
# ![5.10.png](attachment:5.10.png)
